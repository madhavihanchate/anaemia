# %%
import numpy as np 
import os 

print(os.getcwd())
# os.chdir('..')

from dataloader.conjuctiva_loader import load_conjunctiva_dataset
from dataloader.palm_loader import load_palm_dataset
from dataloader.nails_loader import load_nails_dataset

Xc, yc = load_conjunctiva_dataset()
Xp, yp = load_palm_dataset()
Xn, yn = load_nails_dataset()

print(Xc.shape, Xp.shape, Xn.shape)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from preprocessing.conjuctiva import preprocess
#
# ImportError: cannot import name 'preprocess' from 'preprocessing.conjuctiva' (c:\Users\BIT\Desktop\anaemia-detection\preprocessing\conjuctiva.py)

# %%
import numpy as np 
import os 

print(os.getcwd())
# os.chdir('..')

from dataloader.conjuctiva_loader import load_conjunctiva_dataset
from dataloader.palm_loader import load_palm_dataset
from dataloader.nails_loader import load_nails_dataset

Xc, yc = load_conjunctiva_dataset()
Xp, yp = load_palm_dataset()
Xn, yn = load_nails_dataset()

print(Xc.shape, Xp.shape, Xn.shape)
# Out:
# c:\Users\BIT\Desktop\anaemia-detection
# Traceback (most recent call last):
#
#   File c:\Users\BIT\Desktop\anaemia-detection\venv\Lib\site-packages\IPython\core\interactiveshell.py:3701 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[14], line 9
#     from dataloader.nails_loader import load_nails_dataset
#
#   File c:\Users\BIT\Desktop\anaemia-detection\dataloader\nails_loader.py:7
#     DATA_DIR = "data\Nails"
#                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 4-5: malformed \N character escape

# %%
import numpy as np

print(Xc.shape)
print("Unique labels:", np.unique(yc))

anaemic_count = np.sum(yc == 1)
non_anaemic_count = np.sum(yc == 0)

print("CONJUNCTIVA Anaemic (label=1):", anaemic_count)
print("CONJUNCTIVA Non-anaemic (label=0):", non_anaemic_count)

print(Xp.shape)
print("Unique labels:", np.unique(yp))

anaemic_count = np.sum(yp == 1)
non_anaemic_count = np.sum(yp == 0)

print("PALM Anaemic (label=1):", anaemic_count)
print("PALM Non-anaemic (label=0):", non_anaemic_count)

print(Xn.shape)
print("Unique labels:", np.unique(yn))

anaemic_count = np.sum(yn == 1)
non_anaemic_count = np.sum(yn == 0)

print("NAILS Anaemic (label=1):", anaemic_count)
print("NAILS Non-anaemic (label=0):", non_anaemic_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 import numpy as np
# ----> 3 print(Xc.shape)
#       4 print("Unique labels:", np.unique(yc))
#       6 anaemic_count = np.sum(yc == 1)
#
# NameError: name 'Xc' is not defined
